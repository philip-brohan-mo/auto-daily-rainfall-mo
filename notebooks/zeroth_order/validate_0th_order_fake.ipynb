# %% [markdown]
# # Validate the original un-fine-tuned models against fake data
#
# This notebook documents the validation of the original un-fine-tuned models against a test set of fake images. It specifies the models to be used, runs an extraction job for the fake test data from each model (on Azure), downloads the extracted transcriptions, and makes validation summaries comparing the transcriptions with the ground truth for the fake test data.
#
# After completing this notebook, we know how well the un-fine-tuned models do on the fake data. This gives a baseline to judge the effect of fine-tuning.

# %%
import subprocess

# Define the models to be used.
# Each model is associated with a name, the batch size for processing, and the number of shards to split the workload into.
# Label, model name, batch size, no.of shards
MODEL_JOBS = [
    (
        "SmolVLM",
        "smolvlm2",
        50,1,
    ),
    (
        "Granite4",
        "granite4",
        50,1,
    ),
    (
        "Gemma3",
        "gemma3",
        50,1,
    ),
    (
        "Gemma4",
        "gemma4",
        50,1,
    ),
    (
        "Ministral",
        "ministral",
        15,1,
    ),
]

# %% [markdown]
# ## 2. Run the extractions
#
# The code cell below submits one extraction job for each of the five models.
# It relies on the MODEL_JOBS dictionary defined in the cell above.
#
# There are only 64 images in the test set, so these jobs will run in 15 mins or so (+queueing time).

# %%
for model_name, model, batch_size, total_shards, in MODEL_JOBS:
    print(f"Submitting {model_name}...")
    subprocess.run(
        [
            "bash",
            "../../scripts/aml_submit.sh",
            "--model",
            model,
            "--images-path",   # on Azure
            "test_data/fake/images",
            "--transcriptions-path", # Ground-truth dir (metadata only)
            "test_data/fake/transcriptions",
            "--total-shards",
            str(total_shards),
            "--batch-size",
            str(batch_size),
            "--extraction-registry", # Local path
            "../../outputs/extraction_registry.json",
            "extract",
        ],
        check=True,
    )
# Out:
# Submitting SmolVLM...
# Workspace:  mlw-llmdatarescue-uksouth-01  (rg-climate-llmdatarescue / 79c7890c-2a30-44ef-aa8d-419d25b7bb8e)
# Compute:    A100x8
# GPU workers per node: 8
# Finetune GPU processes: 8
# Grad accum steps (base): 8
# Auto-scale grad accum:   true
# Model:      smolvlm2
# Images:     azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/test_data/fake/images
# Outputs:    azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/Daily_rainfall_sample/outputs
#
# Submitting 1 extract shard(s)...
#   Output:   azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/Daily_rainfall_sample/outputs/extractions/smolvlm2/20260624-143502
#   HF cache: azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/hf_cache
#   Shard 1 / 1 ...
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteConditionSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseAutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class IntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ProtectionLevelSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseIntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Uploading Auto-Daily-Rainfall-MO (89.04 MBs): 100%|██████████| 89039165/89039165 [00:01<00:00, 67175011.33it/s]
# epic_horse_3f4pncgbhv
# Added extraction registry: ../../outputs/extraction_registry.json
#   Run: 20260624-143502
#   Model: smolvlm2
#   Dataset: test_data/fake/images
# Submitted 1 extract job(s).
# Extraction registry: ../../outputs/extraction_registry.json
# Submitting Granite4...
# Workspace:  mlw-llmdatarescue-uksouth-01  (rg-climate-llmdatarescue / 79c7890c-2a30-44ef-aa8d-419d25b7bb8e)
# Compute:    A100x8
# GPU workers per node: 8
# Finetune GPU processes: 8
# Grad accum steps (base): 8
# Auto-scale grad accum:   true
# Model:      granite4
# Images:     azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/test_data/fake/images
# Outputs:    azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/Daily_rainfall_sample/outputs
#
# Submitting 1 extract shard(s)...
#   Output:   azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/Daily_rainfall_sample/outputs/extractions/granite4/20260624-143536
#   HF cache: azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/hf_cache
#   Shard 1 / 1 ...
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteConditionSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseAutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class IntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ProtectionLevelSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseIntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# goofy_date_50lryblq0p
# Added extraction registry: ../../outputs/extraction_registry.json
#   Run: 20260624-143536
#   Model: granite4
#   Dataset: test_data/fake/images
# Submitted 1 extract job(s).
# Extraction registry: ../../outputs/extraction_registry.json
# Submitting Gemma3...
# Workspace:  mlw-llmdatarescue-uksouth-01  (rg-climate-llmdatarescue / 79c7890c-2a30-44ef-aa8d-419d25b7bb8e)
# Compute:    A100x8
# GPU workers per node: 8
# Finetune GPU processes: 8
# Grad accum steps (base): 8
# Auto-scale grad accum:   true
# Model:      gemma3
# Images:     azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/test_data/fake/images
# Outputs:    azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/Daily_rainfall_sample/outputs
#
# Submitting 1 extract shard(s)...
#   Output:   azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/Daily_rainfall_sample/outputs/extractions/gemma3/20260624-143552
#   HF cache: azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/hf_cache
#   Shard 1 / 1 ...
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteConditionSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseAutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class IntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ProtectionLevelSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseIntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# olive_yuca_r1y1chxhfv
# Added extraction registry: ../../outputs/extraction_registry.json
#   Run: 20260624-143552
#   Model: gemma3
#   Dataset: test_data/fake/images
# Submitted 1 extract job(s).
# Extraction registry: ../../outputs/extraction_registry.json
# Submitting Gemma4...
# Workspace:  mlw-llmdatarescue-uksouth-01  (rg-climate-llmdatarescue / 79c7890c-2a30-44ef-aa8d-419d25b7bb8e)
# Compute:    A100x8
# GPU workers per node: 8
# Finetune GPU processes: 8
# Grad accum steps (base): 8
# Auto-scale grad accum:   true
# Model:      gemma4
# Images:     azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/test_data/fake/images
# Outputs:    azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/Daily_rainfall_sample/outputs
#
# Submitting 1 extract shard(s)...
#   Output:   azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/Daily_rainfall_sample/outputs/extractions/gemma4/20260624-143604
#   HF cache: azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/hf_cache
#   Shard 1 / 1 ...
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteConditionSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseAutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class IntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ProtectionLevelSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseIntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# mango_ticket_82pzs29xdj
# Added extraction registry: ../../outputs/extraction_registry.json
#   Run: 20260624-143604
#   Model: gemma4
#   Dataset: test_data/fake/images
# Submitted 1 extract job(s).
# Extraction registry: ../../outputs/extraction_registry.json
# Submitting Ministral...
# Workspace:  mlw-llmdatarescue-uksouth-01  (rg-climate-llmdatarescue / 79c7890c-2a30-44ef-aa8d-419d25b7bb8e)
# Compute:    A100x8
# GPU workers per node: 8
# Finetune GPU processes: 8
# Grad accum steps (base): 8
# Auto-scale grad accum:   true
# Model:      ministral
# Images:     azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/test_data/fake/images
# Outputs:    azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/Daily_rainfall_sample/outputs
#
# Submitting 1 extract shard(s)...
#   Output:   azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/Daily_rainfall_sample/outputs/extractions/ministral/20260624-143618
#   HF cache: azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/hf_cache
#   Shard 1 / 1 ...
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteConditionSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseAutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class IntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ProtectionLevelSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseIntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# dreamy_calypso_c72kpm91ys
# Added extraction registry: ../../outputs/extraction_registry.json
#   Run: 20260624-143618
#   Model: ministral
#   Dataset: test_data/fake/images
# Submitted 1 extract job(s).
# Extraction registry: ../../outputs/extraction_registry.json

# %% [markdown]
# When the jobs have been submitted, the extraction registry will contain the run names we need to download and analyze the extractions.
#
# Run Cell 6 to discover run names from the registry.
# Then copy the printed `RUN_NAMES = [...]` block into Cell 7 so the run names are stored directly in this notebook.

# %%
import json
from datetime import datetime, timezone
from pathlib import Path
from posixpath import normpath

# Discover run names from extraction registry after submissions complete.
# This cell does NOT write external files. It prints a block to paste into Cell 7.

REGISTRY_PATH = Path("../../outputs/extraction_registry.json")
TARGET_IMAGES_PATH = "test_data/fake/images"


def _norm_rel(path_like: str) -> str:
    return normpath(path_like.replace("\\", "/")).lstrip("./")


def _parse_created_at(value: str) -> datetime:
    if not value:
        return datetime.min.replace(tzinfo=timezone.utc)
    try:
        return datetime.fromisoformat(value.replace("Z", "+00:00"))
    except ValueError:
        return datetime.min.replace(tzinfo=timezone.utc)


registry = json.loads(REGISTRY_PATH.read_text(encoding="utf-8"))
entries = registry.get("extractions", [])

RUN_NAMES = []
missing = []
target_images_norm = _norm_rel(TARGET_IMAGES_PATH)

for model_name, model, _batch_size, _total_shards in MODEL_JOBS:
    candidates = [
        e
        for e in entries
        if _norm_rel(str(e.get("images_path", ""))) == target_images_norm
        and str(e.get("model_slug", "")) == model
        and e.get("run_name")
    ]
    if not candidates:
        missing.append(model_name)
        continue
    best = max(
        candidates,
        key=lambda e: _parse_created_at(str(e.get("created_at", ""))),
    )
    run_name = str(best["run_name"] )
    RUN_NAMES.append(run_name)
    print(f"{model_name}: {run_name}")

if missing:
    raise RuntimeError(
        "Missing extraction runs in registry for: "
        + ", ".join(missing)
        + ". Run the extraction submission cell first, then re-run this cell."
    )

EXTRACTION_DIRS = [f"../../outputs/extractions/{r}" for r in RUN_NAMES]

print("\nCopy this block into Cell 7:\n")
print("RUN_NAMES = [")
for run_name in RUN_NAMES:
    print(f'    "{run_name}",')
print("]\n")
print('EXTRACTION_DIRS = [f"../../outputs/extractions/{r}" for r in RUN_NAMES]')
# Out:
# SmolVLM: 20260624-143502
# Granite4: 20260624-143536
# Gemma3: 20260624-143552
# Gemma4: 20260624-143604
# Ministral: 20260624-143618
#
# Copy this block into Cell 7:
#
# RUN_NAMES = [
#     "20260624-143502",
#     "20260624-143536",
#     "20260624-143552",
#     "20260624-143604",
#     "20260624-143618",
# ]
#
# EXTRACTION_DIRS = [f"../../outputs/extractions/{r}" for r in RUN_NAMES]

# %%
# Persistent run names for this notebook.
# Paste the RUN_NAMES block printed by Cell 6 here.
RUN_NAMES = [
    "20260624-143502",
    "20260624-143536",
    "20260624-143552",
    "20260624-143604",
    "20260624-143618",
]

EXTRACTION_DIRS = [f"../../outputs/extractions/{r}" for r in RUN_NAMES]

if not RUN_NAMES:
    raise RuntimeError("RUN_NAMES is empty. Run Cell 6, then paste its output here.")

print("Using run names:")
for run_name in RUN_NAMES:
    print("  ", run_name)
# Out:
# Using run names:
#    20260624-143502
#    20260624-143536
#    20260624-143552
#    20260624-143604
#    20260624-143618

# %% [markdown]
# When the jobs have completed successfully, download the extractions so we can analyze them locally.

# %%
import subprocess

for run_name in RUN_NAMES:
    subprocess.run(
        ["bash", "../../scripts/aml_download.sh", "--run-name", run_name],
        check=True,
    )
# Out:
# Resolving datastore 'large_datastore' in workspace 'mlw-llmdatarescue-uksouth-01'...
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Storage account: sallmdatarescue02  container: default
#
# Downloading from: Daily_rainfall_sample/outputs/extractions/smolvlm2/20260624-143502
#              to:  /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/extractions/20260624-143502
#          workers: 16
#            quiet: false
#   DRain_1851-1860_Kent-851.json
#   DRain_1861-1870_Buckinghamshire-569.json
#   DRain_1861-1870_Devon-805.json
#   DRain_1861-1870_Northumberland-503.json
#   DRain_1861-1870_Worcestershire-331.json
#   DRain_1871-1880_Bedfordshire-552.json
#   DRain_1871-1880_Bedfordshire-759.json
#   DRain_1871-1880_Cambridgeshire-366.json
#   DRain_1871-1880_Flintshire-261.json
#   DRain_1871-1880_Leicestershire-947.json
#   DRain_1871-1880_Middlesex-660.json
#   DRain_1871-1880_Suffolk-906.json
#   DRain_1881-1890_Hampshire-128.json
#   DRain_1881-1890_Northamptonshire-338.json
#   DRain_1881-1890_Northumberland-177.json
#   DRain_1881-1890_Sussex-6.json
#   DRain_1891-1900_Cumberland-171.json
#   DRain_1891-1900_Cumberland-405.json
#   DRain_1891-1900_Flintshire-492.json
#   DRain_1891-1900_Northumberland-518.json
#   DRain_1891-1900_Oxfordshire-742.json
#   DRain_1891-1900_Surrey-89.json
#   DRain_1891-1900_Yorkshire-217.json
#   DRain_1901-1910_Essex-225.json
#   DRain_1901-1910_Herefordshire-177.json
#   DRain_1901-1910_Herefordshire-619.json
#   DRain_1901-1910_Leicestershire-317.json
#   DRain_1901-1910_Middlesex-364.json
#   DRain_1901-1910_Sussex-211.json
#   DRain_1911-1920_Cumberland-145.json
#   DRain_1911-1920_Essex-57.json
#   DRain_1911-1920_Essex-608.json
#   DRain_1911-1920_Flintshire-182.json
#   DRain_1911-1920_Lancashire-762.json
#   DRain_1911-1920_Nottinghamshire-791.json
#   DRain_1911-1920_Oxfordshire-719.json
#   DRain_1911-1920_Shropshire-283.json
#   DRain_1891-1900_Flintshire-492.json
#   DRain_1891-1900_Northumberland-518.json
#   DRain_1891-1900_Oxfordshire-742.json
#   DRain_1891-1900_Surrey-89.json
#   DRain_1891-1900_Yorkshire-217.json
#   DRain_1901-1910_Essex-225.json
#   DRain_1901-1910_Herefordshire-177.json
#   DRain_1901-1910_Herefordshire-619.json
#   DRain_1901-1910_Leicestershire-317.json
#   DRain_1901-1910_Middlesex-364.json
#   DRain_1901-1910_Sussex-211.json
#   DRain_1911-1920_Cumberland-145.json
#   DRain_1911-1920_Essex-57.json
#   DRain_1911-1920_Essex-608.json
#   DRain_1911-1920_Flintshire-182.json
#   DRain_1911-1920_Lancashire-762.json
#   DRain_1911-1920_Nottinghamshire-791.json
#   DRain_1911-1920_Oxfordshire-719.json
#   DRain_1911-1920_Shropshire-283.json
#   DRain_1911-1920_Suffolk-178.json
#   DRain_1911-1920_Suffolk-403.json
#   DRain_1911-1920_Worcestershire-732.json
#   DRain_1921-1930_Cheshire-778.json
#   DRain_1921-1930_Gloucestershire-9.json
#   DRain_1921-1930_Northamptonshire-709.json
#   DRain_1921-1930_Worcestershire-614.json
#   DRain_1931-1940_Buckinghamshire-146.json
#   DRain_1931-1940_Durham-853.json
#   DRain_1931-1940_Durham-998.json
#   DRain_1931-1940_Essex-743.json
#   DRain_1931-1940_Nottinghamshire-737.json
#   DRain_1931-1940_Rutland-396.json
#   DRain_1931-1940_Suffolk-236.json
#   DRain_1931-1940_Surrey-859.json
#   DRain_1931-1940_Sussex-997.json
#   DRain_1931-1940_Yorkshire-338.json
#   DRain_1941-1950_Cornwall-73.json
#   DRain_1941-1950_Derbyshire-799.json
#   DRain_1941-1950_Essex-226.json
#   DRain_1941-1950_Essex-986.json
#   DRain_1941-1950_Gloucestershire-860.json
#   DRain_1941-1950_Somerset-476.json
#   DRain_1951-1960_Buckinghamshire-124.json
#   DRain_1951-1960_Gloucestershire-602.json
#   DRain_1951-1960_Surrey-818.json
#   DRain_1951-1960_Worcestershire-230.json
# Downloaded 64 files (0 markers skipped, 0 errors).
# Done.

# %% [markdown]
# Make a consensus from the downloaded extractions, and compare with the ground-truth human-transcribed values for each image.
#
# Run the code cell below to build consensus and validation figures.
#
# This produces a consensus in `../../outputs/consensus_fake_data/test_0th_order` with transcriptions, summary, and validation figures for all cases.

# %%
import subprocess

cmd = [
    "bash",
    "../../scripts/run_consensus_pipeline.sh",
    "--dataset-root",
    "../../outputs/consensus_fake_data",
    "--images-dir",
    "../../test_data/fake/images",
    "--variant-name",
    "test_0th_order",
    "--threshold",
    "3",  # minimum number of transcriptions required to form a consensus
    "--null-threshold",
    "5", # minimum number of transcriptions required to form a consensus for null
    "--precision",
    "3",
]

for extraction_dir in EXTRACTION_DIRS:
    cmd.extend(["--extraction-dir", extraction_dir])

cmd.extend(
    [
        "--validate",
        "--ground-truth-dir",
        "../../test_data/fake/transcriptions",
        "--validation-sample-denominator",
        "1",
    ]
)

subprocess.run(cmd, check=True)
# Out:
# === Consensus Pipeline ===
# Dataset root:      ../../outputs/consensus_fake_data
# Variant name:      test_0th_order
# Threshold:         3
# Null threshold:    5
# Precision:         3
# Extraction dirs:   5
# Validate:          true
# Validation sample: 1/1
#
# Warning: config already exists at ../../outputs/consensus_fake_data/test_0th_order/consensus_config.json
# Running non-interactively; overwriting existing config.
# Creating config...
# ✓ Created consensus config
#   Variant:           test_0th_order
#   Dataset root:      /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data
#   Variant dir:       /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order
#   Config file:       /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/consensus_config.json
#   Extraction dirs:   5 model(s)
#                      1. /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/extractions/20260624-143502
#                      2. /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/extractions/20260624-143536
#                      3. /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/extractions/20260624-143552
#                      4. /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/extractions/20260624-143604
#                      5. /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/extractions/20260624-143618
#   Agreement thresh:  3
#   Null thresh:       5
#   Precision:         3
#
# Building consensus transcriptions...
# {
#   "total_stems": 64,
#   "total_cells": 24576,
#   "correct_cells": 4183,
#   "incorrect_cells": 20393,
#   "missing_model_files": 0,
#   "parse_failed_or_invalid": 13,
#   "input_dirs": [
#     "/home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/extractions/20260624-143502",
#     "/home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/extractions/20260624-143536",
#     "/home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/extractions/20260624-143552",
#     "/home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/extractions/20260624-143604",
#     "/home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/extractions/20260624-143618"
#   ],
#   "agreement_threshold": 3,
#   "null_threshold": 5,
#   "precision": 3,
#   "agreement_coverage": 0.170207
# }
#
# ✓ Consensus built successfully
#   Config:           ../../outputs/consensus_fake_data/test_0th_order/consensus_config.json
#   Consensus output: ../../outputs/consensus_fake_data/test_0th_order/consensus_transcriptions/
#   Summary:          ../../outputs/consensus_fake_data/test_0th_order/consensus_summary.json
#
# Generating validation figures...
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1851-1860_Kent-851_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1861-1870_Buckinghamshire-569_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1861-1870_Devon-805_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1861-1870_Northumberland-503_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1861-1870_Worcestershire-331_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1871-1880_Bedfordshire-552_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1871-1880_Bedfordshire-759_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1871-1880_Cambridgeshire-366_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1871-1880_Flintshire-261_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1871-1880_Leicestershire-947_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1871-1880_Middlesex-660_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1871-1880_Suffolk-906_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1881-1890_Hampshire-128_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1881-1890_Northamptonshire-338_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1881-1890_Northumberland-177_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1881-1890_Sussex-6_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1891-1900_Cumberland-171_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1891-1900_Cumberland-405_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1891-1900_Flintshire-492_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1891-1900_Northumberland-518_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1891-1900_Oxfordshire-742_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1891-1900_Surrey-89_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1891-1900_Yorkshire-217_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1901-1910_Essex-225_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1901-1910_Herefordshire-177_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1901-1910_Herefordshire-619_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1901-1910_Leicestershire-317_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1901-1910_Middlesex-364_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1901-1910_Sussex-211_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1911-1920_Cumberland-145_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1911-1920_Essex-57_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1911-1920_Essex-608_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1911-1920_Flintshire-182_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1911-1920_Lancashire-762_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1911-1920_Nottinghamshire-791_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1911-1920_Oxfordshire-719_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1911-1920_Shropshire-283_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1911-1920_Suffolk-178_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1911-1920_Suffolk-403_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1911-1920_Worcestershire-732_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1921-1930_Cheshire-778_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1921-1930_Gloucestershire-9_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1921-1930_Northamptonshire-709_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1921-1930_Worcestershire-614_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1931-1940_Buckinghamshire-146_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1931-1940_Durham-853_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1931-1940_Durham-998_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1931-1940_Essex-743_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1931-1940_Nottinghamshire-737_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1931-1940_Rutland-396_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1931-1940_Suffolk-236_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1931-1940_Surrey-859_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1931-1940_Sussex-997_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1931-1940_Yorkshire-338_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1941-1950_Cornwall-73_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1941-1950_Derbyshire-799_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1941-1950_Essex-226_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1941-1950_Essex-986_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1941-1950_Gloucestershire-860_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1941-1950_Somerset-476_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1951-1960_Buckinghamshire-124_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1951-1960_Gloucestershire-602_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1951-1960_Surrey-818_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/validation_figures/DRain_1951-1960_Worcestershire-230_comparison.png
# Done. Saved 64 figure(s); skipped 0.
# Updated summary: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/consensus_summary.json
# ✓ Validation figures saved
#   Figures: ../../outputs/consensus_fake_data/test_0th_order/validation_figures/
#
# === Pipeline Complete ===
# CompletedProcess(args=['bash', '../../scripts/run_consensus_pipeline.sh', '--dataset-root', '../../outputs/consensus_fake_data', '--images-dir', '../../test_data/fake/images', '--variant-name', 'test_0th_order', '--threshold', '3', '--null-threshold', '5', '--precision', '3', '--extraction-dir', '../../outputs/extractions/20260624-143502', '--extraction-dir', '../../outputs/extractions/20260624-143536', '--extraction-dir', '../../outputs/extractions/20260624-143552', '--extraction-dir', '../../outputs/extractions/20260624-143604', '--extraction-dir', '../../outputs/extractions/20260624-143618', '--validate', '--ground-truth-dir', '../../test_data/fake/transcriptions', '--validation-sample-denominator', '1'], returncode=0)

# %% [markdown]
# ## 3. Score each individual extraction against ground truth
#
# This step computes per-model extraction quality directly against ground-truth transcriptions.
#
# Metrics reported per extraction include:
# - `accuracy_vs_all_ground_truth_cells`: correct cells divided by all ground-truth cells
# - `accuracy_on_evaluated_cells`: correct cells divided by cells from successfully parsed outputs
# - `coverage_of_ground_truth_cells`: fraction of ground-truth cells with valid extracted values

# %%
import subprocess
from pathlib import Path

labels = [name for name, _model, _batch, _shards in MODEL_JOBS]

cmd = [
    "python",
    "../../scripts/evaluate_extraction_quality.py",
    "--ground-truth-dir",
    "../../test_data/fake/transcriptions",
    "--output-json",
    "../../outputs/consensus_fake_data/test_0th_order/extraction_quality_summary.json",
]

for label, extraction_dir in zip(labels, EXTRACTION_DIRS):
    cmd.extend(["--extraction-dir", extraction_dir, "--label", label])

subprocess.run(cmd, check=True)

print("\nSaved quality summary to:")
print(Path("../../outputs/consensus_fake_data/test_0th_order/extraction_quality_summary.json").resolve())
# Out:
# EXTRACTION QUALITY SUMMARY
# ========================================================================================================================
# Label         Acc(all) Acc(eval)  Coverage  Correct  Incorrect Cells(eval)   Miss    Bad
# ----------------------------------------------------------------------------------------
# Granite4        0.8677    0.8677    1.0000    21324       3252       24576      0      0
# Ministral       0.6038    0.6038    1.0000    14840       9736       24576      0      0
# Gemma4          0.2787    0.3075    0.9062     6849      15423       22272      0      6
# Gemma3          0.2269    0.2421    0.9375     5577      17463       23040      0      4
# SmolVLM         0.2061    0.2162    0.9531     5065      18359       23424      0      3
#
# Wrote summary JSON: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/extraction_quality_summary.json
#
# Saved quality summary to:
# /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/test_0th_order/extraction_quality_summary.json
