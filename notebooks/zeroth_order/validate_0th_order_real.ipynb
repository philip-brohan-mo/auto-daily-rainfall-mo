# %% [markdown]
# # Validate the original un-fine-tuned models against real data
#
# This notebook documents the validation of the original un-fine-tuned models against a test set of daily rainfall images manually transcribed and provided by Ciara Ryan. It specifies the models to be used, runs an extraction job for the test images from each model (on Azure), downloads the extracted transcriptions, and makes validation summaries comparing the transcriptions with the manually-transcribed ground truth.
#
# After completing this notebook, we know how well the un-fine-tuned models do on the test images. This gives a baseline to judge the effect of fine-tuning.

# %%
import subprocess

# Define the models to be used.
# Each model is associated with a name, the batch size for processing, and the number of shards to split the workload into.
# Label, model name, batch size, no.of shards
MODEL_JOBS = [
    (
        "SmolVLM",
        "smolvlm2",
        50,1,
    ),
    (
        "Granite4",
        "granite4",
        50,1,
    ),
    (
        "Gemma3",
        "gemma3",
        50,1,
    ),
    (
        "Gemma4",
        "gemma4",
        50,1,
    ),
    (
        "Ministral",
        "ministral",
        15,1,
    ),
]

# %% [markdown]
# ## 2. Run the extractions
#
# The code cell below submits one extraction job for each of the five models.
# It relies on the MODEL_JOBS dictionary defined in the cell above.
#
# There are only 64 images in the test set, so these jobs will run in 15 mins or so (+queueing time).

# %%
for model_name, model, batch_size, total_shards, in MODEL_JOBS:
    print(f"Submitting {model_name}...")
    subprocess.run(
        [
            "bash",
            "../../scripts/aml_submit.sh",
            "--model",
            model,
            "--images-path",   # on Azure
            "test_data/from_Ciara/images",
            "--transcriptions-path", # Ground-truth dir (metadata only)
            "test_data/from_Ciara/transcriptions",
            "--total-shards",
            str(total_shards),
            "--batch-size",
            str(batch_size),
            "--extraction-registry", # Local path
            "../../outputs/extraction_registry.json",
            "extract",
        ],
        check=True,
    )
# Out:
# Submitting SmolVLM...
# Workspace:  mlw-llmdatarescue-uksouth-01  (rg-climate-llmdatarescue / 79c7890c-2a30-44ef-aa8d-419d25b7bb8e)
# Compute:    A100x8
# GPU workers per node: 8
# Finetune GPU processes: 8
# Grad accum steps (base): 8
# Auto-scale grad accum:   true
# Model:      smolvlm2
# Images:     azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/test_data/from_Ciara/images
# Outputs:    azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/Daily_rainfall_sample/outputs
#
# Submitting 1 extract shard(s)...
#   Output:   azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/Daily_rainfall_sample/outputs/extractions/smolvlm2/20260624-163819
#   HF cache: azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/hf_cache
#   Shard 1 / 1 ...
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteConditionSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseAutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class IntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ProtectionLevelSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseIntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Uploading Auto-Daily-Rainfall-MO (89.14 MBs): 100%|██████████| 89143469/89143469 [00:01<00:00, 59524603.49it/s]
# yellow_parsnip_kvz9lnfzw6
# Added extraction registry: ../../outputs/extraction_registry.json
#   Run: 20260624-163819
#   Model: smolvlm2
#   Dataset: test_data/from_Ciara/images
# Submitted 1 extract job(s).
# Extraction registry: ../../outputs/extraction_registry.json
# Submitting Granite4...
# Workspace:  mlw-llmdatarescue-uksouth-01  (rg-climate-llmdatarescue / 79c7890c-2a30-44ef-aa8d-419d25b7bb8e)
# Compute:    A100x8
# GPU workers per node: 8
# Finetune GPU processes: 8
# Grad accum steps (base): 8
# Auto-scale grad accum:   true
# Model:      granite4
# Images:     azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/test_data/from_Ciara/images
# Outputs:    azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/Daily_rainfall_sample/outputs
#
# Submitting 1 extract shard(s)...
#   Output:   azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/Daily_rainfall_sample/outputs/extractions/granite4/20260624-163850
#   HF cache: azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/hf_cache
#   Shard 1 / 1 ...
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteConditionSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseAutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class IntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ProtectionLevelSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseIntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# affable_machine_rkx489r6xd
# Added extraction registry: ../../outputs/extraction_registry.json
#   Run: 20260624-163850
#   Model: granite4
#   Dataset: test_data/from_Ciara/images
# Submitted 1 extract job(s).
# Extraction registry: ../../outputs/extraction_registry.json
# Submitting Gemma3...
# Workspace:  mlw-llmdatarescue-uksouth-01  (rg-climate-llmdatarescue / 79c7890c-2a30-44ef-aa8d-419d25b7bb8e)
# Compute:    A100x8
# GPU workers per node: 8
# Finetune GPU processes: 8
# Grad accum steps (base): 8
# Auto-scale grad accum:   true
# Model:      gemma3
# Images:     azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/test_data/from_Ciara/images
# Outputs:    azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/Daily_rainfall_sample/outputs
#
# Submitting 1 extract shard(s)...
#   Output:   azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/Daily_rainfall_sample/outputs/extractions/gemma3/20260624-163910
#   HF cache: azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/hf_cache
#   Shard 1 / 1 ...
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteConditionSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseAutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class IntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ProtectionLevelSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseIntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# joyful_lychee_gfn1qg9px0
# Added extraction registry: ../../outputs/extraction_registry.json
#   Run: 20260624-163910
#   Model: gemma3
#   Dataset: test_data/from_Ciara/images
# Submitted 1 extract job(s).
# Extraction registry: ../../outputs/extraction_registry.json
# Submitting Gemma4...
# Workspace:  mlw-llmdatarescue-uksouth-01  (rg-climate-llmdatarescue / 79c7890c-2a30-44ef-aa8d-419d25b7bb8e)
# Compute:    A100x8
# GPU workers per node: 8
# Finetune GPU processes: 8
# Grad accum steps (base): 8
# Auto-scale grad accum:   true
# Model:      gemma4
# Images:     azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/test_data/from_Ciara/images
# Outputs:    azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/Daily_rainfall_sample/outputs
#
# Submitting 1 extract shard(s)...
#   Output:   azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/Daily_rainfall_sample/outputs/extractions/gemma4/20260624-163929
#   HF cache: azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/hf_cache
#   Shard 1 / 1 ...
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteConditionSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseAutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class IntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ProtectionLevelSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseIntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# jovial_garlic_tmb84rgwm0
# Added extraction registry: ../../outputs/extraction_registry.json
#   Run: 20260624-163929
#   Model: gemma4
#   Dataset: test_data/from_Ciara/images
# Submitted 1 extract job(s).
# Extraction registry: ../../outputs/extraction_registry.json
# Submitting Ministral...
# Workspace:  mlw-llmdatarescue-uksouth-01  (rg-climate-llmdatarescue / 79c7890c-2a30-44ef-aa8d-419d25b7bb8e)
# Compute:    A100x8
# GPU workers per node: 8
# Finetune GPU processes: 8
# Grad accum steps (base): 8
# Auto-scale grad accum:   true
# Model:      ministral
# Images:     azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/test_data/from_Ciara/images
# Outputs:    azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/Daily_rainfall_sample/outputs
#
# Submitting 1 extract shard(s)...
#   Output:   azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/Daily_rainfall_sample/outputs/extractions/ministral/20260624-163947
#   HF cache: azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths/hf_cache
#   Shard 1 / 1 ...
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteConditionSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseAutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class IntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ProtectionLevelSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseIntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# calm_board_qtbr4zxcfn
# Added extraction registry: ../../outputs/extraction_registry.json
#   Run: 20260624-163947
#   Model: ministral
#   Dataset: test_data/from_Ciara/images
# Submitted 1 extract job(s).
# Extraction registry: ../../outputs/extraction_registry.json

# %% [markdown]
# When the jobs have been submitted, the extraction registry will contain the run names we need to download and analyze the extractions.
#
# Run Cell 6 to discover run names from the registry.
# Then copy the printed `RUN_NAMES = [...]` block into Cell 7 so the run names are stored directly in this notebook.

# %%
import json
from datetime import datetime, timezone
from pathlib import Path
from posixpath import normpath

# Discover run names from extraction registry after submissions complete.
# This cell does NOT write external files. It prints a block to paste into Cell 7.

REGISTRY_PATH = Path("../../outputs/extraction_registry.json")
TARGET_IMAGES_PATH = "test_data/from_Ciara/images"


def _norm_rel(path_like: str) -> str:
    return normpath(path_like.replace("\\", "/")).lstrip("./")


def _parse_created_at(value: str) -> datetime:
    if not value:
        return datetime.min.replace(tzinfo=timezone.utc)
    try:
        return datetime.fromisoformat(value.replace("Z", "+00:00"))
    except ValueError:
        return datetime.min.replace(tzinfo=timezone.utc)


registry = json.loads(REGISTRY_PATH.read_text(encoding="utf-8"))
entries = registry.get("extractions", [])

RUN_NAMES = []
missing = []
target_images_norm = _norm_rel(TARGET_IMAGES_PATH)

for model_name, model, _batch_size, _total_shards in MODEL_JOBS:
    candidates = [
        e
        for e in entries
        if _norm_rel(str(e.get("images_path", ""))) == target_images_norm
        and str(e.get("model_slug", "")) == model
        and e.get("run_name")
    ]
    if not candidates:
        missing.append(model_name)
        continue
    best = max(
        candidates,
        key=lambda e: _parse_created_at(str(e.get("created_at", ""))),
    )
    run_name = str(best["run_name"] )
    RUN_NAMES.append(run_name)
    print(f"{model_name}: {run_name}")

if missing:
    raise RuntimeError(
        "Missing extraction runs in registry for: "
        + ", ".join(missing)
        + ". Run the extraction submission cell first, then re-run this cell."
    )

EXTRACTION_DIRS = [f"../../outputs/extractions/{r}" for r in RUN_NAMES]

print("\nCopy this block into Cell 7:\n")
print("RUN_NAMES = [")
for run_name in RUN_NAMES:
    print(f'    "{run_name}",')
print("]\n")
print('EXTRACTION_DIRS = [f"../../outputs/extractions/{r}" for r in RUN_NAMES]')
# Out:
# SmolVLM: 20260624-163819
# Granite4: 20260624-163850
# Gemma3: 20260624-163910
# Gemma4: 20260624-163929
# Ministral: 20260624-163947
#
# Copy this block into Cell 7:
#
# RUN_NAMES = [
#     "20260624-163819",
#     "20260624-163850",
#     "20260624-163910",
#     "20260624-163929",
#     "20260624-163947",
# ]
#
# EXTRACTION_DIRS = [f"../../outputs/extractions/{r}" for r in RUN_NAMES]

# %%
# Persistent run names for this notebook.
# Paste the RUN_NAMES block printed by Cell 6 here.
RUN_NAMES = [
    "20260624-163819",
    "20260624-163850",
    "20260624-163910",
    "20260624-163929",
    "20260624-163947",
]
EXTRACTION_DIRS = [f"../../outputs/extractions/{r}" for r in RUN_NAMES]

if not RUN_NAMES:
    raise RuntimeError("RUN_NAMES is empty. Run Cell 6, then paste its output here.")

print("Using run names:")
for run_name in RUN_NAMES:
    print("  ", run_name)
# Out:
# Using run names:
#    20260624-163819
#    20260624-163850
#    20260624-163910
#    20260624-163929
#    20260624-163947

# %% [markdown]
# When the jobs have completed successfully, download the extractions so we can analyze them locally.

# %%
import subprocess

for run_name in RUN_NAMES:
    subprocess.run(
        ["bash", "../../scripts/aml_download.sh", "--run-name", run_name],
        check=True,
    )
# Out:
# Resolving datastore 'large_datastore' in workspace 'mlw-llmdatarescue-uksouth-01'...
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Storage account: sallmdatarescue02  container: default
#
# Downloading from: Daily_rainfall_sample/outputs/extractions/smolvlm2/20260624-163819
#              to:  /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/extractions/20260624-163819
#          workers: 16
#            quiet: false
#   DRain_1901-1910_Ciara-3613.json
#   DRain_1901-1910_Ciara-3614.json
#   DRain_1901-1910_Ciara-3615.json
#   DRain_1901-1910_Ciara-3616.json
#   DRain_1901-1910_Ciara-3617.json
#   DRain_1901-1910_Ciara-3618.json
#   DRain_1901-1910_Ciara-3619.json
#   DRain_1901-1910_Ciara-3620.json
#   DRain_1901-1910_Ciara-3621.json
#   DRain_1901-1910_Ciara-3622.json
#   DRain_1901-1910_Ciara-3623.json
#   DRain_1901-1910_Ciara-3624.json
#   DRain_1901-1910_Ciara-3625.json
#   DRain_1901-1910_Ciara-3626.json
#   DRain_1901-1910_Ciara-3627.json
#   DRain_1901-1910_Ciara-3628.json
#   DRain_1901-1910_Ciara-3629.json
#   DRain_1901-1910_Ciara-3630.json
#   DRain_1901-1910_Ciara-3667.json
#   DRain_1901-1910_Ciara-3668.json
#   DRain_1901-1910_Ciara-3669.json
#   DRain_1901-1910_Ciara-3670.json
#   DRain_1901-1910_Ciara-3671.json
#   DRain_1901-1910_Ciara-3672.json
#   DRain_1901-1910_Ciara-3673.json
#   DRain_1901-1910_Ciara-3674.json
#   DRain_1901-1910_Ciara-3675.json
#   DRain_1901-1910_Ciara-3676.json
#   DRain_1901-1910_Ciara-3677.json
#   DRain_1901-1910_Ciara-3678.json
#   DRain_1901-1910_Ciara-3679.json
#   DRain_1901-1910_Ciara-3680.json
#   DRain_1901-1910_Ciara-3681.json
#   DRain_1901-1910_Ciara-3682.json
#   DRain_1901-1910_Ciara-3683.json
#   DRain_1901-1910_Ciara-3684.json
#   DRain_1901-1910_Ciara-3685.json
#   DRain_1901-1910_Ciara-3686.json
#   DRain_1901-1910_Ciara-3687.json
#   DRain_1901-1910_Ciara-3688.json
#   DRain_1901-1910_Ciara-3689.json
#   DRain_1901-1910_Ciara-3690.json
#   DRain_1901-1910_Ciara-3691.json
#   DRain_1901-1910_Ciara-5811.json
#   DRain_1901-1910_Ciara-5812.json
#   DRain_1901-1910_Ciara-5813.json
#   DRain_1901-1910_Ciara-5814.json
#   DRain_1901-1910_Ciara-5815.json
#   DRain_1901-1910_Ciara-5818.json
#   DRain_1901-1910_Ciara-5819.json
#   DRain_1901-1910_Ciara-5820.json
#   DRain_1901-1910_Ciara-5821.json
#   DRain_1901-1910_Ciara-5822.json
#   DRain_1901-1910_Ciara-5823.json
#   DRain_1901-1910_Ciara-5824.json
#   DRain_1901-1910_Ciara-5825.json
#   DRain_1901-1910_Ciara-5826.json
#   DRain_1901-1910_Ciara-5827.json
#   DRain_1901-1910_Ciara-5828.json
#   DRain_1901-1910_Ciara-5829.json
#   DRain_1901-1910_Ciara-5830.json
#   DRain_1901-1910_Ciara-5831.json
# Downloaded 64 files (0 markers skipped, 0 errors).
# Done.

# %% [markdown]
# Make a consensus from the downloaded extractions, and compare with the ground-truth human-transcribed values for each image.
#
# Run the code cell below to build consensus and validation figures.
#
# This produces a consensus in `../../outputs/consensus_fake_data/test_0th_order` with transcriptions, summary, and validation figures for all cases.

# %%
import subprocess

cmd = [
    "bash",
    "../../scripts/run_consensus_pipeline.sh",
    "--dataset-root",
    "../../outputs/consensus_Ciara_data",
    "--images-dir",
    "../../test_data/from_Ciara/images",
    "--variant-name",
    "test_0th_order",
    "--threshold",
    "3",  # minimum number of transcriptions required to form a consensus
    "--null-threshold",
    "5", # minimum number of transcriptions required to form a consensus for null
    "--precision",
    "3",
]

for extraction_dir in EXTRACTION_DIRS:
    cmd.extend(["--extraction-dir", extraction_dir])

cmd.extend(
    [
        "--validate",
        "--ground-truth-dir",
        "../../test_data/from_Ciara/transcriptions",
        "--validation-sample-denominator",
        "1",
    ]
)

subprocess.run(cmd, check=True)
# Out:
# === Consensus Pipeline ===
# Dataset root:      ../../outputs/consensus_Ciara_data
# Variant name:      test_0th_order
# Threshold:         3
# Null threshold:    5
# Precision:         3
# Extraction dirs:   5
# Validate:          true
# Validation sample: 1/1
#
# Warning: config already exists at ../../outputs/consensus_Ciara_data/test_0th_order/consensus_config.json
# Running non-interactively; overwriting existing config.
# Creating config...
# ✓ Created consensus config
#   Variant:           test_0th_order
#   Dataset root:      /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data
#   Variant dir:       /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order
#   Config file:       /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/consensus_config.json
#   Extraction dirs:   5 model(s)
#                      1. /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/extractions/20260624-163819
#                      2. /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/extractions/20260624-163850
#                      3. /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/extractions/20260624-163910
#                      4. /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/extractions/20260624-163929
#                      5. /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/extractions/20260624-163947
#   Agreement thresh:  3
#   Null thresh:       5
#   Precision:         3
#
# Building consensus transcriptions...
# {
#   "total_stems": 64,
#   "total_cells": 24576,
#   "correct_cells": 3205,
#   "incorrect_cells": 21371,
#   "missing_model_files": 0,
#   "parse_failed_or_invalid": 9,
#   "input_dirs": [
#     "/home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/extractions/20260624-163819",
#     "/home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/extractions/20260624-163850",
#     "/home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/extractions/20260624-163910",
#     "/home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/extractions/20260624-163929",
#     "/home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/extractions/20260624-163947"
#   ],
#   "agreement_threshold": 3,
#   "null_threshold": 5,
#   "precision": 3,
#   "agreement_coverage": 0.130412
# }
#
# ✓ Consensus built successfully
#   Config:           ../../outputs/consensus_Ciara_data/test_0th_order/consensus_config.json
#   Consensus output: ../../outputs/consensus_Ciara_data/test_0th_order/consensus_transcriptions/
#   Summary:          ../../outputs/consensus_Ciara_data/test_0th_order/consensus_summary.json
#
# Generating validation figures...
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3613_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3614_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3615_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3616_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3617_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3618_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3619_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3620_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3621_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3622_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3623_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3624_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3625_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3626_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3627_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3628_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3629_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3630_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3667_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3668_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3669_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3670_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3671_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3672_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3673_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3674_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3675_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3676_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3677_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3678_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3679_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3680_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3681_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3682_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3683_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3684_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3685_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3686_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3687_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3688_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3689_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3690_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-3691_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-5811_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-5812_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-5813_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-5814_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-5815_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-5816_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-5817_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-5818_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-5819_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-5820_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-5821_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-5822_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-5823_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-5824_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-5825_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-5826_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-5827_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-5828_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-5829_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-5830_comparison.png
# Figure: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/validation_figures/DRain_1901-1910_Ciara-5831_comparison.png
# Done. Saved 64 figure(s); skipped 0.
# Updated summary: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/consensus_summary.json
# ✓ Validation figures saved
#   Figures: ../../outputs/consensus_Ciara_data/test_0th_order/validation_figures/
#
# === Pipeline Complete ===
# CompletedProcess(args=['bash', '../../scripts/run_consensus_pipeline.sh', '--dataset-root', '../../outputs/consensus_Ciara_data', '--images-dir', '../../test_data/from_Ciara/images', '--variant-name', 'test_0th_order', '--threshold', '3', '--null-threshold', '5', '--precision', '3', '--extraction-dir', '../../outputs/extractions/20260624-163819', '--extraction-dir', '../../outputs/extractions/20260624-163850', '--extraction-dir', '../../outputs/extractions/20260624-163910', '--extraction-dir', '../../outputs/extractions/20260624-163929', '--extraction-dir', '../../outputs/extractions/20260624-163947', '--validate', '--ground-truth-dir', '../../test_data/from_Ciara/transcriptions', '--validation-sample-denominator', '1'], returncode=0)

# %% [markdown]
# ## 3. Score each individual extraction against ground truth
#
# This step computes per-model extraction quality directly against ground-truth transcriptions.
#
# Metrics reported per extraction include:
# - `accuracy_vs_all_ground_truth_cells`: correct cells divided by all ground-truth cells
# - `accuracy_on_evaluated_cells`: correct cells divided by cells from successfully parsed outputs
# - `coverage_of_ground_truth_cells`: fraction of ground-truth cells with valid extracted values

# %%
import subprocess
from pathlib import Path

labels = [name for name, _model, _batch, _shards in MODEL_JOBS]

cmd = [
    "python",
    "../../scripts/evaluate_extraction_quality.py",
    "--ground-truth-dir",
    "../../test_data/from_Ciara/transcriptions",
    "--output-json",
    "../../outputs/consensus_Ciara_data/test_0th_order/extraction_quality_summary.json",
]

for label, extraction_dir in zip(labels, EXTRACTION_DIRS):
    cmd.extend(["--extraction-dir", extraction_dir, "--label", label])

subprocess.run(cmd, check=True)

print("\nSaved quality summary to:")
print(Path("../../outputs/consensus_Ciara_data/test_0th_order/extraction_quality_summary.json").resolve())
# Out:
# EXTRACTION QUALITY SUMMARY
# ========================================================================================================================
# Label         Acc(all) Acc(eval)  Coverage  Correct  Incorrect Cells(eval)   Miss    Bad
# ----------------------------------------------------------------------------------------
# Ministral       0.6158    0.6158    1.0000    15135       9441       24576      0      0
# Granite4        0.4594    0.4594    1.0000    11289      13287       24576      0      0
# Gemma4          0.3936    0.3936    1.0000     9673      14903       24576      0      0
# SmolVLM         0.3183    0.3183    1.0000     7822      16754       24576      0      0
# Gemma3          0.1780    0.2072    0.8594     4375      16745       21120      0      9
#
# Wrote summary JSON: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/extraction_quality_summary.json
#
# Saved quality summary to:
# /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_Ciara_data/test_0th_order/extraction_quality_summary.json
