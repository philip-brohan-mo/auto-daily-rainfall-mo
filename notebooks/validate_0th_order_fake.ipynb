# %% [markdown]
# # Validate the consensus from the original un-fine-tuned models against fake test data
#
# This notebook documents the validation of the original un-fine-tuned models against fake images.

# %%
import subprocess

# Define the models to be used for validation.
# Each model is associated with a name, the batch size for processing, and the number of shards to split the workload into.
# Label, model name, batch size, no.of shards
MODEL_JOBS = [
    (
        "SmolVLM",
        "smolvlm2",
        50,1,
    ),
    (
        "Granite4",
        "granite4",
        50,1,
    ),
    (
        "Gemma3",
        "gemma3",
        50,1,
    ),
    (
        "Gemma4",
        "gemma4",
        50,1,
    ),
    (
        "Ministral",
        "ministral",
        15,1,
    ),
]

# %% [markdown]
# ## 2. Run the extractions
#
# The code cell below submits one extraction job for each of the five models.
# It relies on the MODEL_JOBS dictionary defined in the cell above.
#
# There are only 64 images in the test set, so these jobs will run in 15 mins or so (+queueing time).

# %%
for model_name, model, batch_size, total_shards, in MODEL_JOBS:
    print(f"Submitting {model_name}...")
    subprocess.run(
        [
            "bash",
            "../scripts/aml_submit.sh",
            "--model",
            model,
            "--images-path",
            "test_data/fake/images",
            "--transcriptions-path",
            "documents/DailyRainfall_UK/test_data/fake/transcriptions_0",
            "--total-shards",
            str(total_shards),
            "--batch-size",
            str(batch_size),
            "--extraction-registry",
            "../outputs/extraction_registry.json",
            "extract",
        ],
        check=True,
    )
# Out:
# Submitting SmolVLM...
# Workspace:  mlw-llmdatarescue-uksouth-01  (rg-climate-llmdatarescue / 79c7890c-2a30-44ef-aa8d-419d25b7bb8e)
# Compute:    A100x1
# Model:      smolvlm2
# Images:     azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths//test_data/fake/images
# Outputs:    azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths//Daily_rainfall_sample/outputs
#
# Submitting 1 extract shard(s)...
#   Output:   azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths//Daily_rainfall_sample/outputs/extractions/smolvlm2/20260618-161908
#   HF cache: azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths//hf_cache
#   Shard 1 / 1 ...
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteConditionSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseAutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class IntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ProtectionLevelSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseIntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Uploading Auto-Daily-Rainfall-MO (88.88 MBs): 100%|██████████| 88880383/88880383 [00:01<00:00, 62399532.99it/s]
# olden_camel_n5tnz9mlcn
# Added extraction registry: ../outputs/extraction_registry.json
#   Run: 20260618-161908
#   Model: smolvlm2
#   Dataset: test_data/fake/images
# Submitted 1 extract job(s).
# Extraction registry: ../outputs/extraction_registry.json
# Submitting Granite4...
# Workspace:  mlw-llmdatarescue-uksouth-01  (rg-climate-llmdatarescue / 79c7890c-2a30-44ef-aa8d-419d25b7bb8e)
# Compute:    A100x1
# Model:      granite4
# Images:     azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths//test_data/fake/images
# Outputs:    azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths//Daily_rainfall_sample/outputs
#
# Submitting 1 extract shard(s)...
#   Output:   azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths//Daily_rainfall_sample/outputs/extractions/granite4/20260618-161939
#   HF cache: azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths//hf_cache
#   Shard 1 / 1 ...
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteConditionSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseAutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class IntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ProtectionLevelSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseIntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# helpful_reggae_sjjl65b1q8
# Added extraction registry: ../outputs/extraction_registry.json
#   Run: 20260618-161939
#   Model: granite4
#   Dataset: test_data/fake/images
# Submitted 1 extract job(s).
# Extraction registry: ../outputs/extraction_registry.json
# Submitting Gemma3...
# Workspace:  mlw-llmdatarescue-uksouth-01  (rg-climate-llmdatarescue / 79c7890c-2a30-44ef-aa8d-419d25b7bb8e)
# Compute:    A100x1
# Model:      gemma3
# Images:     azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths//test_data/fake/images
# Outputs:    azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths//Daily_rainfall_sample/outputs
#
# Submitting 1 extract shard(s)...
#   Output:   azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths//Daily_rainfall_sample/outputs/extractions/gemma3/20260618-161958
#   HF cache: azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths//hf_cache
#   Shard 1 / 1 ...
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteConditionSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseAutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class IntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ProtectionLevelSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseIntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# nifty_glove_b1brb8j56y
# Added extraction registry: ../outputs/extraction_registry.json
#   Run: 20260618-161958
#   Model: gemma3
#   Dataset: test_data/fake/images
# Submitting Gemma4...
# Submitted 1 extract job(s).
# Extraction registry: ../outputs/extraction_registry.json
# Workspace:  mlw-llmdatarescue-uksouth-01  (rg-climate-llmdatarescue / 79c7890c-2a30-44ef-aa8d-419d25b7bb8e)
# Compute:    A100x1
# Model:      gemma4
# Images:     azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths//test_data/fake/images
# Outputs:    azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths//Daily_rainfall_sample/outputs
#
# Submitting 1 extract shard(s)...
#   Output:   azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths//Daily_rainfall_sample/outputs/extractions/gemma4/20260618-162018
#   HF cache: azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths//hf_cache
#   Shard 1 / 1 ...
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteConditionSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseAutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class IntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ProtectionLevelSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseIntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# amusing_bee_mgmchf89lk
# Added extraction registry: ../outputs/extraction_registry.json
#   Run: 20260618-162018
#   Model: gemma4
#   Dataset: test_data/fake/images
# Submitted 1 extract job(s).
# Extraction registry: ../outputs/extraction_registry.json
# Submitting Ministral...
# Workspace:  mlw-llmdatarescue-uksouth-01  (rg-climate-llmdatarescue / 79c7890c-2a30-44ef-aa8d-419d25b7bb8e)
# Compute:    A100x1
# Model:      ministral
# Images:     azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths//test_data/fake/images
# Outputs:    azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths//Daily_rainfall_sample/outputs
#
# Submitting 1 extract shard(s)...
#   Output:   azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths//Daily_rainfall_sample/outputs/extractions/ministral/20260618-162038
#   HF cache: azureml://subscriptions/79c7890c-2a30-44ef-aa8d-419d25b7bb8e/resourcegroups/rg-climate-llmdatarescue/workspaces/mlw-llmdatarescue-uksouth-01/datastores/large_datastore/paths//hf_cache
#   Shard 1 / 1 ...
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteConditionSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseAutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class IntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ProtectionLevelSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseIntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# careful_bag_ybdnl8fxq6
# Added extraction registry: ../outputs/extraction_registry.json
#   Run: 20260618-162038
#   Model: ministral
#   Dataset: test_data/fake/images
# Submitted 1 extract job(s).
# Extraction registry: ../outputs/extraction_registry.json

# %% [markdown]
# When the jobs have been submitted, the extraction registry will contain the run names we need to download and analyze the extractions.
#
# Run Cell 6 to discover run names from the registry.
# Then copy the printed `RUN_NAMES = [...]` block into Cell 7 so the run names are stored directly in this notebook.

# %%
import json
from datetime import datetime, timezone
from pathlib import Path
from posixpath import normpath

# Discover run names from extraction registry after submissions complete.
# This cell does NOT write external files. It prints a block to paste into Cell 7.


def _first_existing_path(candidates: list[Path]) -> Path:
    for p in candidates:
        if p.exists():
            return p
    return candidates[0]


REGISTRY_PATH = _first_existing_path(
    [Path("outputs/extraction_registry.json"), Path("../outputs/extraction_registry.json")]
 )
TARGET_IMAGES_PATH = "test_data/fake/images"


def _norm_rel(path_like: str) -> str:
    return normpath(path_like.replace("\\", "/")).lstrip("./")


def _parse_created_at(value: str) -> datetime:
    if not value:
        return datetime.min.replace(tzinfo=timezone.utc)
    try:
        return datetime.fromisoformat(value.replace("Z", "+00:00"))
    except ValueError:
        return datetime.min.replace(tzinfo=timezone.utc)


registry = json.loads(REGISTRY_PATH.read_text(encoding="utf-8"))
entries = registry.get("extractions", [])

RUN_NAMES = []
missing = []
target_images_norm = _norm_rel(TARGET_IMAGES_PATH)

for model_name, model, _batch_size, _total_shards in MODEL_JOBS:
    candidates = [
        e
        for e in entries
        if _norm_rel(str(e.get("images_path", ""))) == target_images_norm
        and str(e.get("model_slug", "")) == model
        and e.get("run_name")
    ]
    if not candidates:
        missing.append(model_name)
        continue
    best = max(
        candidates,
        key=lambda e: _parse_created_at(str(e.get("created_at", ""))),
    )
    run_name = str(best["run_name"] )
    RUN_NAMES.append(run_name)
    print(f"{model_name}: {run_name}")

if missing:
    raise RuntimeError(
        "Missing extraction runs in registry for: "
        + ", ".join(missing)
        + ". Run the extraction submission cell first, then re-run this cell."
    )

EXTRACTION_DIRS = [f"../outputs/extractions/{r}" for r in RUN_NAMES]

print("\nCopy this block into Cell 7:\n")
print("RUN_NAMES = [")
for run_name in RUN_NAMES:
    print(f'    "{run_name}",')
print("]\n")
print('EXTRACTION_DIRS = [f"../outputs/extractions/{r}" for r in RUN_NAMES]')
# Out:
# SmolVLM: 20260618-161908
# Granite4: 20260618-161939
# Gemma3: 20260618-161958
# Gemma4: 20260618-162018
# Ministral: 20260618-162038
#
# Copy this block into Cell 7:
#
# RUN_NAMES = [
#     "20260618-161908",
#     "20260618-161939",
#     "20260618-161958",
#     "20260618-162018",
#     "20260618-162038",
# ]
#
# EXTRACTION_DIRS = [f"../outputs/extractions/{r}" for r in RUN_NAMES]

# %%
# Persistent run names for this notebook.
# Paste the RUN_NAMES block printed by Cell 6 here.
RUN_NAMES = [
    "20260618-161908",
    "20260618-161939",
    "20260618-161958",
    "20260618-162018",
    "20260618-162038",
]

EXTRACTION_DIRS = [f"../outputs/extractions/{r}" for r in RUN_NAMES]

if not RUN_NAMES:
    raise RuntimeError("RUN_NAMES is empty. Run Cell 6, then paste its output here.")

print("Using run names:")
for run_name in RUN_NAMES:
    print("  ", run_name)
# Out:
# Using run names:
#    20260618-161908
#    20260618-161939
#    20260618-161958
#    20260618-162018
#    20260618-162038

# %% [markdown]
# When the jobs have completed successfully, download the extractions so we can analyze them locally.

# %%
import subprocess

for run_name in RUN_NAMES:
    subprocess.run(
        ["bash", "../scripts/aml_download.sh", "--run-name", run_name],
        check=True,
    )

# %% [markdown]
# Make a consensus from the downloaded extractions, and compare with the ground-truth human-transcribed values for each image.
#
# Run the code cell below to build consensus and validation figures.
#
# This produces a consensus in `outputs/consensus_fake_data/consensus_0th_order` with transcriptions, summary, and validation figures for all cases.

# %%
import subprocess

cmd = [
    "bash",
    "../scripts/run_consensus_pipeline.sh",
    "--dataset-root",
    "../outputs/consensus_fake_data",
    "--variant-name",
    "consensus_0th_order",
    "--threshold",
    "3",  # minimum number of transcriptions required to form a consensus
    "--null-threshold",
    "5", # minimum number of transcriptions required to form a consensus for null
    "--precision",
    "3",
]

for extraction_dir in EXTRACTION_DIRS:
    cmd.extend(["--extraction-dir", extraction_dir])

cmd.extend(
    [
        "--validate",
        "--ground-truth-dir",
        "../test_data/fake/transcriptions",
        "--validation-sample-denominator",
        "1",
    ]
)

subprocess.run(cmd, check=True)

# %% [markdown]
# ## 3. Score each individual extraction against ground truth
#
# This step computes per-model extraction quality directly against ground-truth transcriptions.
#
# Metrics reported per extraction include:
# - `accuracy_vs_all_ground_truth_cells`: correct cells divided by all ground-truth cells
# - `accuracy_on_evaluated_cells`: correct cells divided by cells from successfully parsed outputs
# - `coverage_of_ground_truth_cells`: fraction of ground-truth cells with valid extracted values

# %%
import subprocess
from pathlib import Path

labels = [name for name, _model, _batch, _shards in MODEL_JOBS]

cmd = [
    "python",
    "../scripts/evaluate_extraction_quality.py",
    "--ground-truth-dir",
    "../test_data/fake/transcriptions",
    "--output-json",
    "../outputs/consensus_fake_data/consensus_0th_order/extraction_quality_summary.json",
]

for label, extraction_dir in zip(labels, EXTRACTION_DIRS):
    cmd.extend(["--extraction-dir", extraction_dir, "--label", label])

subprocess.run(cmd, check=True)

print("\nSaved quality summary to:")
print(Path("../outputs/consensus_fake_data/consensus_0th_order/extraction_quality_summary.json").resolve())
# Out:
# EXTRACTION QUALITY SUMMARY
# ========================================================================================================================
# Label         Acc(all) Acc(eval)  Coverage  Correct  Incorrect Cells(eval)   Miss    Bad
# ----------------------------------------------------------------------------------------
# Granite4        0.8721    0.8721    1.0000    21433       3143       24576      0      0
# Ministral       0.5931    0.6025    0.9844    14575       9617       24192      0      1
# Gemma4          0.2794    0.3083    0.9062     6867      15405       22272      0      6
# Gemma3          0.2366    0.2523    0.9375     5814      17226       23040      0      4
# SmolVLM         0.2020    0.2120    0.9531     4965      18459       23424      0      3
#
# Saved quality summary to:
# /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/consensus_0th_order/extraction_quality_summary.json
#
# Wrote summary JSON: /home/users/philip.brohan/Projects/Auto-Daily-Rainfall-MO/outputs/consensus_fake_data/consensus_0th_order/extraction_quality_summary.json
